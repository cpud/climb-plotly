# %%
# Trying to get hyperlinks for all states so we can run the scraping script on all states.

# Imports and get the html data from MountainProject. 
import pandas as pd
import numpy as np
import string
import requests
from bs4 import BeautifulSoup

url = 'https://www.mountainproject.com/area/105905173/alabama'
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')

# Put all hyperlinks on the page into a list.
data = []
for climb in soup.find_all('td'):
    data.append(climb.text)
    
# List of US States that we'll use to remove unwanted hyperlinks.
# Mississippi and Nebrasaka don't have pages, which makes sense,
# considering how flat they are.
states = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New-Hampshire","New-Jersey","New-Mexico","New-York",
  "North-Carolina","North-Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode-Island","South-Carolina","South-Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West-Virginia","Wisconsin","Wyoming"]

# List of US States and their abbreviations for a dictionary.
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New-Hampshire': 'NH',
    'New-Jersey': 'NJ',
    'New-Mexico': 'NM',
    'New-York': 'NY',
    'North-Carolina': 'NC',
    'North-Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode-Island': 'RI',
    'South-Carolina': 'SC',
    'South-Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West-Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# Make the states lowercase to match hyperlinks. 
states = [x.lower() for x in states]
us_state_abbrev = dict((k.lower(),v) for k,v in us_state_abbrev.items())

# %%
data
# Out:
# ['Elevation:',
#  '572 ft',
#  'GPS:',
#  '\n                        33.761, -86.88\n                        Google\n                            Map · Climbing Area Map\n',
#  'Page Views:',
#  '\n                    1,372,104 total ·\n                    8,632/month\n                ',
#  'Shared By:',
#  '\nsaxfiend\n            on Jan 5, 2007\n                    ',
#  'Admins:',
#  '\nsaxfiend,    Brad "Stonyman" Killough ',
#  '\n                    Location:\n                ',
#  '\n\nAlabama Change\n\n    function changeAreaPickerLocation(mode, includeRoutes) {\n        var id = $("#initial-id-"+mode).val();\n        if (!id) {\n            id = 0;\n        }\n        showModalDlgFromAjax(\n            // mode should be "single" or "multi"\n            \'/ajax/public/area-picker/\' + id + "?mode="+mode+"&routes="+includeRoutes,\n            \'\',\n            [\'modal-md\', \'\']\n        );\n    }\n\n',
#  '\n                    Type:\n                ',
#  '\n\nRock\nBoulder\nAid\nIce\nMixed\n\n\n3rd\n4th\n5.0\n5.1\n5.2\n5.3\n5.4\n5.5\n5.6\n5.7\n5.8\n5.9\n5.10a\n5.10b\n5.10c\n5.10d\n5.11a\n5.11b\n5.11c\n5.11d\n5.12a\n5.12b\n5.12c\n5.12d\n5.13a\n5.13b\n5.13c\n5.13d\n5.14a\n5.14b\n5.14c\n5.14d\n5.15a\n5.15b\n5.15c\n5.15d\n\n\nV0\nV1\nV2\nV3\nV4\nV5\nV6\nV7\nV8\nV9\nV10\nV11\nV12\nV13\nV14\nV15\nV16\nV17\n\n\nA0/C0\nA1/C1\nA2/C2\nA3/C3\nA4/C4\nA5/C5\n\n\nWI1\nWI2\nWI3\nWI4\nWI5\nWI6\nWI7\nWI8\nAI1\nAI2\nAI3\nAI4\nAI5\nAI6\n\n\nM1\nM2\nM3\nM4\nM5\nM6\nM7\nM8\nM9\nM10\nM11\n\n                \xa0to\xa0\n                \n3rd\n4th\n5.0\n5.1\n5.2\n5.3\n5.4\n5.5\n5.6\n5.7\n5.8\n5.9\n5.10a\n5.10b\n5.10c\n5.10d\n5.11a\n5.11b\n5.11c\n5.11d\n5.12a\n5.12b\n5.12c\n5.12d\n5.13a\n5.13b\n5.13c\n5.13d\n5.14a\n5.14b\n5.14c\n5.14d\n5.15a\n5.15b\n5.15c\n5.15d\n\n\nV0\nV1\nV2\nV3\nV4\nV5\nV6\nV7\nV8\nV9\nV10\nV11\nV12\nV13\nV14\nV15\nV16\nV17\n\n\nA0/C0\nA1/C1\nA2/C2\nA3/C3\nA4/C4\nA5/C5\n\n\nWI1\nWI2\nWI3\nWI4\nWI5\nWI6\nWI7\nWI8\nAI1\nAI2\nAI3\nAI4\nAI5\nAI6\n\n\nM1\nM2\nM3\nM4\nM5\nM6\nM7\nM8\nM9\nM10\nM11\n\n\n\n Trad\n        \n\n Sport\n        \n\n Toprope\n        \n\n',
#  '\n                    Quality:\n                ',
#  '\n\nAll routes\n1+ of 4 stars\n1.5+ of 4 stars\n2+ of 4 stars\n2.5+ of 4 stars\n3+ of 4 stars\n\n',
#  '\n                    Pitches:\n                ',
#  '\n\nAny number\nExactly 1\nAt least 2\nAt least 3\nAt least 4\nAt least 5\n6+ pitches\n\n',
#  '\n                    Sort by:\n                ',
#  '\n\nArea\nDifficulty\nPopularity\nName\n\xa0\n                    then: \nArea\nDifficulty\nPopularity\nName\n\n',
#  '\xa0',
#  '\n\n',
#  '\n\n\nV2 5+\n\n\n\n\n\n\n\n\n\xa099\n\n\n\n●\nThe Stranger \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Spirit Area\n\n',
#  '\n\n\nV2-3 5+\n\n\n\n\n\n\n\n\n\xa086\n\n\n\n●\nCopa Cabana \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Ten Pins Area\n\n',
#  '\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n●\nGenesis \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nTemp HP40\n\n',
#  '\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n●\nEarth Wind & Fire \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n',
#  '\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa0200\n\n\n\n●\nBumboy \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Supa Coola Area/ Mill…\n\n',
#  '\n\n\nV4 6B\n\n\n\n\n\n\n\n\n\xa073\n\n\n\n●\nLowdown \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Mulletino Boulder.\n\n',
#  '\n\n\nV5 6C\n\n\n\n\n\n\n\n\n\n\xa091\n\n\n\n●\nHammerhead \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n',
#  '\n\n\n5.6 4c 14 V 12 S 4b\n\n\n\n\n\n\n\n\n\xa0106\n\n\n\n●\nKnob Wall \n\n\n\n\n\n        \n        \n                    Trad \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n',
#  '\n\n\n5.8 5b 16 VI- 15 HVS 4c\n\n\n\n\n\n\n\n\n\xa0193\n\n\n\n●\nThat Eight (aka Kennel Club) \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n',
#  '\n\n\n5.9 5c 17 VI 17 HVS 5a\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n●\nComfortably Numb \n\n\n\n\n\n        \n        \n                    Trad, TR \n            \n\n\n\nSand Rock\n        \n             > Pinnacle\n\n',
#  '\n\n\n5.10a 6a 18 VI+ 18 E1 5a\n\n\n\n\n\n\n\n\n\xa0179\n\n\n\n●\nOyster \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n',
#  '\n\n\n5.10b/c 6b 20 VII 20 E2 5b\n\n\n\n\n\n\n\n\n\n\xa0203\n\n\n\n●\nMisty \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n',
#  '\n\n\n5.10c/d 6b+ 21 VII+ 21 E3 5b\n\n\n\n\n\n\n\n\n\xa093\n\n\n\n●\nCinco de Mayo \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n',
#  "\n\n\n5.10d 6b+ 21 VII+ 21 E3 5b\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n●\nPigs in Zen (Tuesday's Gone) \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n",
#  '\n\n\n5.11c 6c+ 24 VIII- 24 E4 6a\n\n\n\n\n\n\n\n\n\n\xa0100\n\n\n\n●\nDreamscape \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n',
#  '\n●\nThe Stranger\n',
#  '\n\n\nHorse Pens 40\n        \n             > Spirit Area\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa099\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa099\n',
#  '\nV2 5+\n\n\nBoulder \n\n',
#  '\n●\nCopa Cabana\n',
#  '\n\n\nHorse Pens 40\n        \n             > Ten Pins Area\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa086\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa086\n',
#  '\nV2-3 5+\n\n\nBoulder \n\n',
#  '\n●\nGenesis\n',
#  '\n\n\nTemp HP40\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa080\n',
#  '\nV3 6A\n\n\nBoulder \n\n',
#  '\n●\nEarth Wind & Fire\n',
#  '\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa083\n',
#  '\nV3 6A\n\n\nBoulder \n\n',
#  '\n●\nBumboy\n',
#  '\n\n\nHorse Pens 40\n        \n             > Supa Coola Area/ Mill…\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa0200\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa0200\n',
#  '\nV3 6A\n\n\nBoulder \n\n',
#  '\n●\nLowdown\n',
#  '\n\n\nHorse Pens 40\n        \n             > Mulletino Boulder.\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa073\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa073\n',
#  '\nV4 6B\n\n\nBoulder \n\n',
#  '\n●\nHammerhead\n',
#  '\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa091\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa091\n',
#  '\nV5 6C\n\n\nBoulder \n\n',
#  '\n●\nKnob Wall\n',
#  '\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0106\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa0106\n',
#  '\n5.6 4c 14 V 12 S 4b\n\n\nTrad \n\n',
#  '\n●\nThat Eight (aka Kennel Club)\n',
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0193\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa0193\n',
#  '\n5.8 5b 16 VI- 15 HVS 4c\n\n\nSport \n\n',
#  '\n●\nComfortably Numb\n',
#  '\n\n\nSand Rock\n        \n             > Pinnacle\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa083\n',
#  '\n5.9 5c 17 VI 17 HVS 5a\n\n\nTrad, TR \n\n',
#  '\n●\nOyster\n',
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0179\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa0179\n',
#  '\n5.10a 6a 18 VI+ 18 E1 5a\n\n\nSport \n\n',
#  '\n●\nMisty\n',
#  '\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa0203\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa0203\n',
#  '\n5.10b/c 6b 20 VII 20 E2 5b\n\n\nSport \n\n',
#  '\n●\nCinco de Mayo\n',
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa093\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa093\n',
#  '\n5.10c/d 6b+ 21 VII+ 21 E3 5b\n\n\nSport \n\n',
#  "\n●\nPigs in Zen (Tuesday's Gone)\n",
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa080\n',
#  '\n5.10d 6b+ 21 VII+ 21 E3 5b\n\n\nSport \n\n',
#  '\n●\nDreamscape\n',
#  '\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa0100\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa0100\n',
#  '\n5.11c 6c+ 24 VIII- 24 E4 6a\n\n\nSport \n\n',
#  '\nHigh\n\xa0\n',
#  '\nLow\n\xa0\n',
#  '\nPrecip\n\xa0\n',
#  '\nDays w Precip\n\xa0\n',
#  'J',
#  'F',
#  'M',
#  'A',
#  'M',
#  'J',
#  'J',
#  'A',
#  'S',
#  'O',
#  'N',
#  'D',
#  'J',
#  'F',
#  'M',
#  'A',
#  'M',
#  'J',
#  'J',
#  'A',
#  'S',
#  'O',
#  'N',
#  'D']

# %%
blah = pd.DataFrame(list(filter(None,data)))

# %%
blah.columns = ['text']

# %%
blah['Climbs'] = [s.strip() for s in blah['text']]

# %%
blah.head()
# Out:
#                                                 text  \
# 0                                         Elevation:
# 1                                             572 ft
# 2                                               GPS:
# 3  \n                        33.761, -86.88\n    ...
# 4                                        Page Views:
#
#                                               Climbs
# 0                                         Elevation:
# 1                                             572 ft
# 2                                               GPS:
# 3  33.761, -86.88\n                        Google...
# 4                                        Page Views:

# %%
blah['Climbs']
# Out:
# 0                                             Elevation:
# 1                                                 572 ft
# 2                                                   GPS:
# 3      33.761, -86.88\n                        Google...
# 4                                            Page Views:
# 5      1,372,104 total ·\n                    8,632/m...
# 6                                             Shared By:
# 7                   saxfiend\n            on Jan 5, 2007
# 8                                                Admins:
# 9                  saxfiend,    Brad "Stonyman" Killough
# 10                                             Location:
# 11     Alabama Change\n\n    function changeAreaPicke...
# 12                                                 Type:
# 13     Rock\nBoulder\nAid\nIce\nMixed\n\n\n3rd\n4th\n...
# 14                                              Quality:
# 15     All routes\n1+ of 4 stars\n1.5+ of 4 stars\n2+...
# 16                                              Pitches:
# 17     Any number\nExactly 1\nAt least 2\nAt least 3\...
# 18                                              Sort by:
# 19     Area\nDifficulty\nPopularity\nName\n \n       ...
# 20
# 21
# 22     V2 5+\n\n\n\n\n\n\n\n\n 99\n\n\n\n●\nThe Stran...
# 23     V2-3 5+\n\n\n\n\n\n\n\n\n 86\n\n\n\n●\nCopa Ca...
# 24     V3 6A\n\n\n\n\n\n\n\n\n\n 80\n\n\n\n●\nGenesis...
# 25     V3 6A\n\n\n\n\n\n\n\n\n\n 83\n\n\n\n●\nEarth W...
# 26     V3 6A\n\n\n\n\n\n\n\n\n\n 200\n\n\n\n●\nBumboy...
# 27     V4 6B\n\n\n\n\n\n\n\n\n 73\n\n\n\n●\nLowdown \...
# 28     V5 6C\n\n\n\n\n\n\n\n\n\n 91\n\n\n\n●\nHammerh...
# 29     5.6 4c 14 V 12 S 4b\n\n\n\n\n\n\n\n\n 106\n\n\...
#                              ...
# 110                                                  100
# 111               5.11c 6c+ 24 VIII- 24 E4 6a\n\n\nSport
# 112                                                 High
# 113                                                  Low
# 114                                               Precip
# 115                                        Days w Precip
# 116                                                    J
# 117                                                    F
# 118                                                    M
# 119                                                    A
# 120                                                    M
# 121                                                    J
# 122                                                    J
# 123                                                    A
# 124                                                    S
# 125                                                    O
# 126                                                    N
# 127                                                    D
# 128                                                    J
# 129                                                    F
# 130                                                    M
# 131                                                    A
# 132                                                    M
# 133                                                    J
# 134                                                    J
# 135                                                    A
# 136                                                    S
# 137                                                    O
# 138                                                    N
# 139                                                    D
# Name: Climbs, Length: 140, dtype: object

# %%
bleh = blah[~blah['Climbs'].str.contains('\n')]

# %%
bleh['Climbs']
# Out:
# 0                                 Elevation:
# 1                                     572 ft
# 2                                       GPS:
# 4                                Page Views:
# 6                                 Shared By:
# 8                                    Admins:
# 9      saxfiend,    Brad "Stonyman" Killough
# 10                                 Location:
# 12                                     Type:
# 14                                  Quality:
# 16                                  Pitches:
# 18                                  Sort by:
# 20
# 21
# 39                                        99
# 40                                        99
# 44                                        86
# 45                                        86
# 48                                 Temp HP40
# 49                                        80
# 50                                        80
# 54                                        83
# 55                                        83
# 59                                       200
# 60                                       200
# 64                                        73
# 65                                        73
# 69                                        91
# 70                                        91
# 74                                       106
#                        ...
# 109                                      100
# 110                                      100
# 112                                     High
# 113                                      Low
# 114                                   Precip
# 115                            Days w Precip
# 116                                        J
# 117                                        F
# 118                                        M
# 119                                        A
# 120                                        M
# 121                                        J
# 122                                        J
# 123                                        A
# 124                                        S
# 125                                        O
# 126                                        N
# 127                                        D
# 128                                        J
# 129                                        F
# 130                                        M
# 131                                        A
# 132                                        M
# 133                                        J
# 134                                        J
# 135                                        A
# 136                                        S
# 137                                        O
# 138                                        N
# 139                                        D
# Name: Climbs, Length: 73, dtype: object

# %%
ugh = soup.find_all('td')

# %%
data
# Out:
# ['Elevation:',
#  '572 ft',
#  'GPS:',
#  '\n                        33.761, -86.88\n                        Google\n                            Map · Climbing Area Map\n',
#  'Page Views:',
#  '\n                    1,372,104 total ·\n                    8,632/month\n                ',
#  'Shared By:',
#  '\nsaxfiend\n            on Jan 5, 2007\n                    ',
#  'Admins:',
#  '\nsaxfiend,    Brad "Stonyman" Killough ',
#  '\n                    Location:\n                ',
#  '\n\nAlabama Change\n\n    function changeAreaPickerLocation(mode, includeRoutes) {\n        var id = $("#initial-id-"+mode).val();\n        if (!id) {\n            id = 0;\n        }\n        showModalDlgFromAjax(\n            // mode should be "single" or "multi"\n            \'/ajax/public/area-picker/\' + id + "?mode="+mode+"&routes="+includeRoutes,\n            \'\',\n            [\'modal-md\', \'\']\n        );\n    }\n\n',
#  '\n                    Type:\n                ',
#  '\n\nRock\nBoulder\nAid\nIce\nMixed\n\n\n3rd\n4th\n5.0\n5.1\n5.2\n5.3\n5.4\n5.5\n5.6\n5.7\n5.8\n5.9\n5.10a\n5.10b\n5.10c\n5.10d\n5.11a\n5.11b\n5.11c\n5.11d\n5.12a\n5.12b\n5.12c\n5.12d\n5.13a\n5.13b\n5.13c\n5.13d\n5.14a\n5.14b\n5.14c\n5.14d\n5.15a\n5.15b\n5.15c\n5.15d\n\n\nV0\nV1\nV2\nV3\nV4\nV5\nV6\nV7\nV8\nV9\nV10\nV11\nV12\nV13\nV14\nV15\nV16\nV17\n\n\nA0/C0\nA1/C1\nA2/C2\nA3/C3\nA4/C4\nA5/C5\n\n\nWI1\nWI2\nWI3\nWI4\nWI5\nWI6\nWI7\nWI8\nAI1\nAI2\nAI3\nAI4\nAI5\nAI6\n\n\nM1\nM2\nM3\nM4\nM5\nM6\nM7\nM8\nM9\nM10\nM11\n\n                \xa0to\xa0\n                \n3rd\n4th\n5.0\n5.1\n5.2\n5.3\n5.4\n5.5\n5.6\n5.7\n5.8\n5.9\n5.10a\n5.10b\n5.10c\n5.10d\n5.11a\n5.11b\n5.11c\n5.11d\n5.12a\n5.12b\n5.12c\n5.12d\n5.13a\n5.13b\n5.13c\n5.13d\n5.14a\n5.14b\n5.14c\n5.14d\n5.15a\n5.15b\n5.15c\n5.15d\n\n\nV0\nV1\nV2\nV3\nV4\nV5\nV6\nV7\nV8\nV9\nV10\nV11\nV12\nV13\nV14\nV15\nV16\nV17\n\n\nA0/C0\nA1/C1\nA2/C2\nA3/C3\nA4/C4\nA5/C5\n\n\nWI1\nWI2\nWI3\nWI4\nWI5\nWI6\nWI7\nWI8\nAI1\nAI2\nAI3\nAI4\nAI5\nAI6\n\n\nM1\nM2\nM3\nM4\nM5\nM6\nM7\nM8\nM9\nM10\nM11\n\n\n\n Trad\n        \n\n Sport\n        \n\n Toprope\n        \n\n',
#  '\n                    Quality:\n                ',
#  '\n\nAll routes\n1+ of 4 stars\n1.5+ of 4 stars\n2+ of 4 stars\n2.5+ of 4 stars\n3+ of 4 stars\n\n',
#  '\n                    Pitches:\n                ',
#  '\n\nAny number\nExactly 1\nAt least 2\nAt least 3\nAt least 4\nAt least 5\n6+ pitches\n\n',
#  '\n                    Sort by:\n                ',
#  '\n\nArea\nDifficulty\nPopularity\nName\n\xa0\n                    then: \nArea\nDifficulty\nPopularity\nName\n\n',
#  '\xa0',
#  '\n\n',
#  '\n\n\nV2 5+\n\n\n\n\n\n\n\n\n\xa099\n\n\n\n●\nThe Stranger \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Spirit Area\n\n',
#  '\n\n\nV2-3 5+\n\n\n\n\n\n\n\n\n\xa086\n\n\n\n●\nCopa Cabana \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Ten Pins Area\n\n',
#  '\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n●\nGenesis \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nTemp HP40\n\n',
#  '\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n●\nEarth Wind & Fire \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n',
#  '\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa0200\n\n\n\n●\nBumboy \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Supa Coola Area/ Mill…\n\n',
#  '\n\n\nV4 6B\n\n\n\n\n\n\n\n\n\xa073\n\n\n\n●\nLowdown \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Mulletino Boulder.\n\n',
#  '\n\n\nV5 6C\n\n\n\n\n\n\n\n\n\n\xa091\n\n\n\n●\nHammerhead \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n',
#  '\n\n\n5.6 4c 14 V 12 S 4b\n\n\n\n\n\n\n\n\n\xa0106\n\n\n\n●\nKnob Wall \n\n\n\n\n\n        \n        \n                    Trad \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n',
#  '\n\n\n5.8 5b 16 VI- 15 HVS 4c\n\n\n\n\n\n\n\n\n\xa0193\n\n\n\n●\nThat Eight (aka Kennel Club) \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n',
#  '\n\n\n5.9 5c 17 VI 17 HVS 5a\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n●\nComfortably Numb \n\n\n\n\n\n        \n        \n                    Trad, TR \n            \n\n\n\nSand Rock\n        \n             > Pinnacle\n\n',
#  '\n\n\n5.10a 6a 18 VI+ 18 E1 5a\n\n\n\n\n\n\n\n\n\xa0179\n\n\n\n●\nOyster \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n',
#  '\n\n\n5.10b/c 6b 20 VII 20 E2 5b\n\n\n\n\n\n\n\n\n\n\xa0203\n\n\n\n●\nMisty \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n',
#  '\n\n\n5.10c/d 6b+ 21 VII+ 21 E3 5b\n\n\n\n\n\n\n\n\n\xa093\n\n\n\n●\nCinco de Mayo \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n',
#  "\n\n\n5.10d 6b+ 21 VII+ 21 E3 5b\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n●\nPigs in Zen (Tuesday's Gone) \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n",
#  '\n\n\n5.11c 6c+ 24 VIII- 24 E4 6a\n\n\n\n\n\n\n\n\n\n\xa0100\n\n\n\n●\nDreamscape \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n',
#  '\n●\nThe Stranger\n',
#  '\n\n\nHorse Pens 40\n        \n             > Spirit Area\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa099\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa099\n',
#  '\nV2 5+\n\n\nBoulder \n\n',
#  '\n●\nCopa Cabana\n',
#  '\n\n\nHorse Pens 40\n        \n             > Ten Pins Area\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa086\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa086\n',
#  '\nV2-3 5+\n\n\nBoulder \n\n',
#  '\n●\nGenesis\n',
#  '\n\n\nTemp HP40\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa080\n',
#  '\nV3 6A\n\n\nBoulder \n\n',
#  '\n●\nEarth Wind & Fire\n',
#  '\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa083\n',
#  '\nV3 6A\n\n\nBoulder \n\n',
#  '\n●\nBumboy\n',
#  '\n\n\nHorse Pens 40\n        \n             > Supa Coola Area/ Mill…\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa0200\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa0200\n',
#  '\nV3 6A\n\n\nBoulder \n\n',
#  '\n●\nLowdown\n',
#  '\n\n\nHorse Pens 40\n        \n             > Mulletino Boulder.\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa073\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa073\n',
#  '\nV4 6B\n\n\nBoulder \n\n',
#  '\n●\nHammerhead\n',
#  '\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa091\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa091\n',
#  '\nV5 6C\n\n\nBoulder \n\n',
#  '\n●\nKnob Wall\n',
#  '\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0106\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa0106\n',
#  '\n5.6 4c 14 V 12 S 4b\n\n\nTrad \n\n',
#  '\n●\nThat Eight (aka Kennel Club)\n',
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0193\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa0193\n',
#  '\n5.8 5b 16 VI- 15 HVS 4c\n\n\nSport \n\n',
#  '\n●\nComfortably Numb\n',
#  '\n\n\nSand Rock\n        \n             > Pinnacle\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa083\n',
#  '\n5.9 5c 17 VI 17 HVS 5a\n\n\nTrad, TR \n\n',
#  '\n●\nOyster\n',
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0179\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa0179\n',
#  '\n5.10a 6a 18 VI+ 18 E1 5a\n\n\nSport \n\n',
#  '\n●\nMisty\n',
#  '\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa0203\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa0203\n',
#  '\n5.10b/c 6b 20 VII 20 E2 5b\n\n\nSport \n\n',
#  '\n●\nCinco de Mayo\n',
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa093\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa093\n',
#  '\n5.10c/d 6b+ 21 VII+ 21 E3 5b\n\n\nSport \n\n',
#  "\n●\nPigs in Zen (Tuesday's Gone)\n",
#  '\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\xa080\n',
#  '\n5.10d 6b+ 21 VII+ 21 E3 5b\n\n\nSport \n\n',
#  '\n●\nDreamscape\n',
#  '\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\xa0100\n\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\xa0100\n',
#  '\n5.11c 6c+ 24 VIII- 24 E4 6a\n\n\nSport \n\n',
#  '\nHigh\n\xa0\n',
#  '\nLow\n\xa0\n',
#  '\nPrecip\n\xa0\n',
#  '\nDays w Precip\n\xa0\n',
#  'J',
#  'F',
#  'M',
#  'A',
#  'M',
#  'J',
#  'J',
#  'A',
#  'S',
#  'O',
#  'N',
#  'D',
#  'J',
#  'F',
#  'M',
#  'A',
#  'M',
#  'J',
#  'J',
#  'A',
#  'S',
#  'O',
#  'N',
#  'D']

# %%
ugh = pd.DataFrame(list(filter(None,data)))

# %%
ugh.columns=['plz']

# %%
ugh[ugh['plz'] == 'Elevation:']
# Out:
#           plz
# 0  Elevation:

# %%
onegai = []
for hope in soup.find_all('table'):
    onegai.append(hope.text)

# %%
onegai
# Out:
# ['\n\nElevation:\n572 ft\n\n\nGPS:\n\n                        33.761, -86.88\n                        Google\n                            Map · Climbing Area Map\n\n\n\nPage Views:\n\n                    1,372,104 total ·\n                    8,632/month\n                \n\n\nShared By:\n\nsaxfiend\n            on Jan 5, 2007\n                    \n\n\nAdmins:\n\nsaxfiend,    Brad "Stonyman" Killough \n\n\n    if (ap.config.isAdmin) {\n        $("#admin-history").removeClass("display-none");\n    }\n\n    $("#view-all-activities-href").click(function(){\n        $("#view-all-activities-href").hide();\n        $("#first-admin-activity").css("display", "block");\n        $("#all-admin-activities").show("fast");\n        return false;\n    });\n ',
#  '\n\n\n                    Location:\n                \n\n\nAlabama Change\n\n    function changeAreaPickerLocation(mode, includeRoutes) {\n        var id = $("#initial-id-"+mode).val();\n        if (!id) {\n            id = 0;\n        }\n        showModalDlgFromAjax(\n            // mode should be "single" or "multi"\n            \'/ajax/public/area-picker/\' + id + "?mode="+mode+"&routes="+includeRoutes,\n            \'\',\n            [\'modal-md\', \'\']\n        );\n    }\n\n\n\n\n\n                    Type:\n                \n\n\nRock\nBoulder\nAid\nIce\nMixed\n\n\n3rd\n4th\n5.0\n5.1\n5.2\n5.3\n5.4\n5.5\n5.6\n5.7\n5.8\n5.9\n5.10a\n5.10b\n5.10c\n5.10d\n5.11a\n5.11b\n5.11c\n5.11d\n5.12a\n5.12b\n5.12c\n5.12d\n5.13a\n5.13b\n5.13c\n5.13d\n5.14a\n5.14b\n5.14c\n5.14d\n5.15a\n5.15b\n5.15c\n5.15d\n\n\nV0\nV1\nV2\nV3\nV4\nV5\nV6\nV7\nV8\nV9\nV10\nV11\nV12\nV13\nV14\nV15\nV16\nV17\n\n\nA0/C0\nA1/C1\nA2/C2\nA3/C3\nA4/C4\nA5/C5\n\n\nWI1\nWI2\nWI3\nWI4\nWI5\nWI6\nWI7\nWI8\nAI1\nAI2\nAI3\nAI4\nAI5\nAI6\n\n\nM1\nM2\nM3\nM4\nM5\nM6\nM7\nM8\nM9\nM10\nM11\n\n                \xa0to\xa0\n                \n3rd\n4th\n5.0\n5.1\n5.2\n5.3\n5.4\n5.5\n5.6\n5.7\n5.8\n5.9\n5.10a\n5.10b\n5.10c\n5.10d\n5.11a\n5.11b\n5.11c\n5.11d\n5.12a\n5.12b\n5.12c\n5.12d\n5.13a\n5.13b\n5.13c\n5.13d\n5.14a\n5.14b\n5.14c\n5.14d\n5.15a\n5.15b\n5.15c\n5.15d\n\n\nV0\nV1\nV2\nV3\nV4\nV5\nV6\nV7\nV8\nV9\nV10\nV11\nV12\nV13\nV14\nV15\nV16\nV17\n\n\nA0/C0\nA1/C1\nA2/C2\nA3/C3\nA4/C4\nA5/C5\n\n\nWI1\nWI2\nWI3\nWI4\nWI5\nWI6\nWI7\nWI8\nAI1\nAI2\nAI3\nAI4\nAI5\nAI6\n\n\nM1\nM2\nM3\nM4\nM5\nM6\nM7\nM8\nM9\nM10\nM11\n\n\n\n Trad\n        \n\n Sport\n        \n\n Toprope\n        \n\n\n\n\n\n                    Quality:\n                \n\n\nAll routes\n1+ of 4 stars\n1.5+ of 4 stars\n2+ of 4 stars\n2.5+ of 4 stars\n3+ of 4 stars\n\n\n\n\n\n                    Pitches:\n                \n\n\nAny number\nExactly 1\nAt least 2\nAt least 3\nAt least 4\nAt least 5\n6+ pitches\n\n\n\n\n\n                    Sort by:\n                \n\n\nArea\nDifficulty\nPopularity\nName\n\xa0\n                    then: \nArea\nDifficulty\nPopularity\nName\n\n\n\n\n\xa0\n\n\n\n\n',
#  "\n\n\n\n\nV2 5+\n\n\n\n\n\n\n\n\n\xa099\n\n\n\n●\nThe Stranger \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Spirit Area\n\n\n\n\n\n\n\nV2-3 5+\n\n\n\n\n\n\n\n\n\xa086\n\n\n\n●\nCopa Cabana \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Ten Pins Area\n\n\n\n\n\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n●\nGenesis \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nTemp HP40\n\n\n\n\n\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n●\nEarth Wind & Fire \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n\n\n\n\n\nV3 6A\n\n\n\n\n\n\n\n\n\n\xa0200\n\n\n\n●\nBumboy \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Supa Coola Area/ Mill…\n\n\n\n\n\n\n\nV4 6B\n\n\n\n\n\n\n\n\n\xa073\n\n\n\n●\nLowdown \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Mulletino Boulder.\n\n\n\n\n\n\n\nV5 6C\n\n\n\n\n\n\n\n\n\n\xa091\n\n\n\n●\nHammerhead \n\n\n\n\n\n        \n        \n                    Boulder \n            \n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n\n\n\n\n\n5.6 4c 14 V 12 S 4b\n\n\n\n\n\n\n\n\n\xa0106\n\n\n\n●\nKnob Wall \n\n\n\n\n\n        \n        \n                    Trad \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n\n\n\n\n\n5.8 5b 16 VI- 15 HVS 4c\n\n\n\n\n\n\n\n\n\xa0193\n\n\n\n●\nThat Eight (aka Kennel Club) \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n5.9 5c 17 VI 17 HVS 5a\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n●\nComfortably Numb \n\n\n\n\n\n        \n        \n                    Trad, TR \n            \n\n\n\nSand Rock\n        \n             > Pinnacle\n\n\n\n\n\n\n\n5.10a 6a 18 VI+ 18 E1 5a\n\n\n\n\n\n\n\n\n\xa0179\n\n\n\n●\nOyster \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n5.10b/c 6b 20 VII 20 E2 5b\n\n\n\n\n\n\n\n\n\n\xa0203\n\n\n\n●\nMisty \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n\n\n\n\n\n5.10c/d 6b+ 21 VII+ 21 E3 5b\n\n\n\n\n\n\n\n\n\xa093\n\n\n\n●\nCinco de Mayo \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n5.10d 6b+ 21 VII+ 21 E3 5b\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n●\nPigs in Zen (Tuesday's Gone) \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n5.11c 6c+ 24 VIII- 24 E4 6a\n\n\n\n\n\n\n\n\n\n\xa0100\n\n\n\n●\nDreamscape \n\n\n\n\n\n        \n        \n                    Sport \n            \n\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n\n",
#  "\n\nRoute Name\nLocation\nStar Rating\nDifficulty\nDate\n\n\n\n●\nThe Stranger\n\n\n\n\nHorse Pens 40\n        \n             > Spirit Area\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa099\n\n\n\n\n\nV2 5+\n\n\nBoulder \n\n\n\n\n\n●\nCopa Cabana\n\n\n\n\nHorse Pens 40\n        \n             > Ten Pins Area\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa086\n\n\n\n\n\nV2-3 5+\n\n\nBoulder \n\n\n\n\n\n●\nGenesis\n\n\n\n\nTemp HP40\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n\n\nV3 6A\n\n\nBoulder \n\n\n\n\n\n●\nEarth Wind & Fire\n\n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n\n\nV3 6A\n\n\nBoulder \n\n\n\n\n\n●\nBumboy\n\n\n\n\nHorse Pens 40\n        \n             > Supa Coola Area/ Mill…\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0200\n\n\n\n\n\nV3 6A\n\n\nBoulder \n\n\n\n\n\n●\nLowdown\n\n\n\n\nHorse Pens 40\n        \n             > Mulletino Boulder.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa073\n\n\n\n\n\nV4 6B\n\n\nBoulder \n\n\n\n\n\n●\nHammerhead\n\n\n\n\nHorse Pens 40\n        \n             > Deck Area/Front Slabs\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa091\n\n\n\n\n\nV5 6C\n\n\nBoulder \n\n\n\n\n\n●\nKnob Wall\n\n\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0106\n\n\n\n\n\n5.6 4c 14 V 12 S 4b\n\n\nTrad \n\n\n\n\n\n●\nThat Eight (aka Kennel Club)\n\n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0193\n\n\n\n\n\n5.8 5b 16 VI- 15 HVS 4c\n\n\nSport \n\n\n\n\n\n●\nComfortably Numb\n\n\n\n\nSand Rock\n        \n             > Pinnacle\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n\n\n\n5.9 5c 17 VI 17 HVS 5a\n\n\nTrad, TR \n\n\n\n\n\n●\nOyster\n\n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0179\n\n\n\n\n\n5.10a 6a 18 VI+ 18 E1 5a\n\n\nSport \n\n\n\n\n\n●\nMisty\n\n\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0203\n\n\n\n\n\n5.10b/c 6b 20 VII 20 E2 5b\n\n\nSport \n\n\n\n\n\n●\nCinco de Mayo\n\n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa093\n\n\n\n\n\n5.10c/d 6b+ 21 VII+ 21 E3 5b\n\n\nSport \n\n\n\n\n\n●\nPigs in Zen (Tuesday's Gone)\n\n\n\n\nSand Rock\n        \n             > Holiday Block\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n\n\n\n5.10d 6b+ 21 VII+ 21 E3 5b\n\n\nSport \n\n\n\n\n\n●\nDreamscape\n\n\n\n\nSand Rock\n        \n             > Sun Wall\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0100\n\n\n\n\n\n5.11c 6c+ 24 VIII- 24 E4 6a\n\n\nSport \n\n\n\n",
#  '\n\n\n\n\n\n\n\n\n\n\xa099\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\xa086\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0200\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\xa073\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa091\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\xa0106\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\xa0193\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa083\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\xa0179\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0203\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\xa093\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\xa080\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\n\xa0100\n\n\n',
#  '\n\n\nHigh\n\xa0\n\n\nLow\n\xa0\n\n\n\n\nPrecip\n\xa0\n\n\nDays w Precip\n\xa0\n\n\n',
#  '\n\nJ\nF\nM\nA\nM\nJ\nJ\nA\nS\nO\nN\nD\n\n',
#  '\n\nJ\nF\nM\nA\nM\nJ\nJ\nA\nS\nO\nN\nD\n\n']
